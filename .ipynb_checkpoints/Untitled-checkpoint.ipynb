# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('resultados-del-test-febrero-octubre-2018.csv', sep=';')

# %%
df2 = pd.read_csv('resultados-del-test.csv')

df2.head()
# Out:
#         fecha      hora  edad  genero        barrio pregunta_1 pregunta_2  \
# 0  2019-06-14  09:09:00    27   Mujer  Constitución          A          A
# 1  2019-06-13  23:20:00    17   Mujer          Otro          A          B
# 2  2019-06-13  16:33:00    15   Mujer      Recoleta          B          B
# 3  2019-06-13  16:10:00    20   Mujer      Barracas          B          C
# 4  2019-06-13  14:29:00    39  Hombre       Almagro          B          C
#
#   pregunta_3 pregunta_4 pregunta_5 pregunta_6 pregunta_7 pregunta_8  \
# 0          A          B          A          B          C          C
# 1          B          B          B          C          C          B
# 2          C          B          C          B          B          A
# 3          C          C          C          C          C          C
# 4          B          B          C          C          B          C
#
#   pregunta_9 pregunta_10 pregunta_11 pregunta_12 pregunta_13
# 0          B           C           B           C           C
# 1          B           C           B           C           C
# 2          A           A           A           A           A
# 3          C           C           B           C           C
# 4          B           C           C           B           C

# %%
# Out:
#             FECHA   HORA EDAD  GENERO            BARRIO PREG_1 PREG_2 PREG_3  \
# 0      13/02/2017  23:41   28  HOMBRE           PALERMO      B      B      B
# 1      13/02/2017  20:09   23   MUJER         BALVANERA      B      B      B
# 2      13/02/2017  20:07   22   MUJER         BALVANERA      A      A      A
# 3      13/02/2017  20:04   34   MUJER  VILLA PUEYRREDON      C      C      B
# 4      13/02/2017  19:34   31   MUJER         CABALLITO      C      C      C
# ...           ...    ...  ...     ...               ...    ...    ...    ...
# 17314         NaN    NaN  NaN     NaN               NaN    NaN    NaN    NaN
# 17315         NaN    NaN  NaN     NaN               NaN    NaN    NaN    NaN
# 17316         NaN    NaN  NaN     NaN               NaN    NaN    NaN    NaN
# 17317         NaN    NaN  NaN     NaN               NaN    NaN    NaN    NaN
# 17318         NaN    NaN  NaN     NaN               NaN    NaN    NaN    NaN
#
#       PREG_4 PREG_5 PREG_6 PREG_7 PREG_8 PREG_9 PREG_10  \
# 0          B      B      B      B      B      B       B
# 1          B      B      B      B      B      B       B
# 2          A      A      A      A      A      B       C
# 3          C      B      C      C      C      C       B
# 4          C      C      C      C      C      C       C
# ...      ...    ...    ...    ...    ...    ...     ...
# 17314    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 17315    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 17316    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 17317    NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 17318    NaN    NaN    NaN    NaN    NaN    NaN     NaN
#
#       fecha,hora,edad,genero,barrio,pregunta_1,pregunta_2,pregunta_3,pregunta_4,pregunta_5,pregunta_6,pregunta_7,pregunta_8,pregunta_9,pregunta_10,pregunta_11,pregunta_12,pregunta_13
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17314  2018-02-14,19:29:00,20,Mujer,Agronomia,B,B,B,B...
# 17315  2018-02-14,19:27:00,26,Mujer,Villa Lugano,B,C,...
# 17316  2018-02-14,19:26:00,18,Mujer,Almagro,B,B,B,B,B...
# 17317  2018-02-14,19:06:00,22,Mujer,Almagro,A,A,A,A,A...
# 17318  2018-02-14,18:51:00,29,Hombre,Agronomia,A,B,C,...
#
# [17319 rows x 16 columns]
